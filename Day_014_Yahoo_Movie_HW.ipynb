# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="501887343352051" property="fb:app_id"/>
# <meta content="Yahoo奇摩電影" property="og:site_name"/>
# <title>Yahoo奇摩電影</title>
# <meta content="Yahoo奇摩電影" name="twitter:title"/>
# <meta content="Yahoo奇摩電影" property="og:title"/>
# <link href="https://movies.yahoo.com.tw" rel="canonical"/>
# <meta content="https://movies.yahoo.com.tw" property="og:url"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="twitter:description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" property="og:description"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" property="og:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image:src"/>
# <meta content="電影, yahoo奇摩電影, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度" name="keywords"/>
# <script type="application/ld+json">
#   {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://movies.yahoo.com.tw",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "/moviesearch_result.html?keyword={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
#   }
# </script> <link href="/build/css/app.css?id=eadc5e22ade55ba173fe&amp;r=1555478321" rel="stylesheet"/>
# <meta content="guce.yahoo.com.tw" name="oath:guce:consent-host"/>
# <!-- Consent Manager Tag : Script -->
# <script async="" src="https://consent.cmp.oath.com/cmp.js" type="text/javascript"></script>
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js" type="text/javascript"></script></head>
# <body id="">
# <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
# <span data-id="794026701" id="ad-space-id"></span>
# <span data-id="2" id="pt-type"></span>
# <!--Website-->
# <div id="maincontainer">
# <header>
# <div id="y-header">
# <nav class="nav content">
# <ul>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']" href="https://tw.yahoo.com/"><span class="icon_home"></span>首頁</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']" href="https://tw.mail.yahoo.com/">信箱</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']" href="https://tw.news.yahoo.com/">新聞</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']" href="https://tw.stock.yahoo.com/">股市</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']" href="https://tw.news.yahoo.com/weather-forecast/">氣象</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']" href="https://tw.sports.yahoo.com/">運動</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']" href="https://tw.news.yahoo.com/entertainment">名人娛樂</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']" href="http://tw.mobile.yahoo.com/">App下載</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']" href="https://tw.buy.yahoo.com/">購物中心</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']" href="https://tw.mall.yahoo.com/">商城</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']" href="https://tw.bid.yahoo.com/">拍賣</a></li>
# <li class="nav_more">
# <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
# <div class="dropdown_list">
# <dl>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']" href="https://tw.video.yahoo.com/">影音</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_知識+','頁首_頻道入口']" href="https://tw.knowledge.yahoo.com/">知識+</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']" href="https://autos.yahoo.com.tw/">汽車機車</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']" href="https://movies.yahoo.com.tw/">電影</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']" href="https://tw.dictionary.yahoo.com/">字典</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']" href="https://games.yahoo.com.tw/">遊戲</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']" href="https://travel.yahoo.com.tw/">旅遊</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']" href="https://tw.money.yahoo.com/">理財</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']" href="https://house.yahoo.com.tw/">房地產</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']" href="https://style.yahoo.com.tw/">時尚美妝</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']" href="https://tw.discount.yahoo.net/index.php?group=all">折扣城</a></dd>
# </dl>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div id="kv">
# <div class="content">
# <div class="_c" id="y_hous_serch">
# <div id="y_serch_l">
# <a class="gabtn" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']" href="https://movies.yahoo.com.tw/index.html" id="ylogo">
# <img alt="Yahoo Logo" src="/build/images/header_logo.png" srcset="/build/images/header_logo@2x.png 2x, /build/images/header_logo@3x.png 3x"/>
# </a>
# <form action="https://tw.search.yahoo.com/search" method="get" target="_blank">
# <input autocomplete="off" id="serchinput" name="p" placeholder="搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden"></div>
# <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">電影‧明星搜尋</button><!--20170531-->
# <button class="gabtn" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']" type="submit">網頁搜尋</button><!--20170531-->
# <input id="fr" name="fr" type="hidden" value="ush-movies"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
# <div class="content">
# <ul id="mainmenu">
# <li><a class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']" href="https://movies.yahoo.com.tw/" target="">
# <span>首頁</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']" href="https://movies.yahoo.com.tw/movie_thisweek.html" target="">
# <span>本週新片</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']" href="https://movies.yahoo.com.tw/movie_intheaters.html" target="">
# <span>上映中</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']" href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="">
# <span>即將上映</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']" href="https://movies.yahoo.com.tw/trailer_index.html" target="">
# <span>預告片</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']" href="https://movies.yahoo.com.tw/chart.html" target="">
# <span>排行榜</span>
# </a></li>
# <li class="hassub">
# <a class="gabtn" data-ga="['選單','選單_情報站','頁首_選單']" href="https://movies.yahoo.com.tw/article_index.html" target="">
# <span>情報站</span></a>
# <div class="submenu">
# <dl class="submenu_inner">
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/movieheadline" target="">
#                               電影新聞</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/spotlight" target="">
#                               專題報導</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/moviereview" target="">
#                               影評</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_精彩圖片','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/slideshow" target="">
#                               精彩圖片</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_懶人卡','頁首_選單']" href="https://tw.youcard.yahoo.com/category/movie" target="_blank">
#                               懶人卡</a></dt>
# </dl>
# </div>
# </li>
# <li><a class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']" href="https://movies.yahoo.com.tw/tv_index.html" target="">
# <span>電視時刻</span>
# </a></li>
# </ul>
# <dl id="sharebox">
# <dt>追蹤我們</dt>
# <dd class="gabtn" data-ga="['選單','選單_追蹤我們','頁首_選單']" onclick="javascript:window.open('https://www.facebook.com/Ymovie/');"></dd>
# </dl>
# </div>
# </div>
# </header>
# <!--主內容-->
# <main>
# <!--top_ad-->
# <div class="maincontent ga_index">
# <div class="boxAD" id="boxMAST"></div>
# <div class="content _c" id="top_serch">
# <div data-topserch="0">
# <div class="tab_serch _c">
# <div class="tab_hot">
# <a class="gabtn" data-ga="['search box','search box_熱門1','北村匠海']" href="https://movies.yahoo.com.tw/movieinfo_main/說再見前的30分鐘-our-30-minutes-session-10561" target="">北村匠海</a>
# <a class="gabtn" data-ga="['search box','search box_熱門2','布魯斯威利']" href="https://movies.yahoo.com.tw/movieinfo_main/惡夜救援-survive-the-night-10634" target="">布魯斯威利</a>
# <a class="gabtn" data-ga="['search box','search box_熱門3','文森卡索']" href="https://movies.yahoo.com.tw/movieinfo_main/在你身邊-the-specials-10567" target="">文森卡索</a>
# </div>
# <a class="btn_booking btn_toptxt gabtn" data-ga="['search box','search box_訂票客服中心','']" href="https://www.ezding.com.tw/page/faq/faq.html" target="_blank">訂票客服中心</a>
# <a class="btn_all btn_toptxt gabtn" data-ga="['search box','search box_戲院總覽','']" href="https://movies.yahoo.com.tw/theater_list.html">戲院總覽</a>
# </div>
# <span data-url="https://movies.yahoo.com.tw" id="mainURL"></span>
# <span data-type="0" id="searchType"></span>
# <div class="tab_serchbar">
# <div class="icon_serch"></div>
# <select id="movie_time" name="search_type">
# <option value="0">電影時刻</option>
# <option value="1">電視時刻</option>
# <option value="2">快速訂票</option>
# <option value="3">電影/明星搜尋</option>
# </select>
# <!--tab_serchbar  style0-->
# <div class="top_change" data-change="0" style="">
# <form action="https://movies.yahoo.com.tw/movietime_result.html" id="form_moviearea" method="get">
# <span>選擇<br/>片名</span>
# <select class="movie_name" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# <option data-name="來自深淵 深沉靈魂的黎明  4DX/MX4D" value="10658">來自深淵 深沉靈魂的黎明  4DX/MX4D</option>
# <option data-name="閉嘴！彈琴" value="10631">閉嘴！彈琴</option>
# <option data-name="素人特工" value="10622">素人特工</option>
# <option data-name="劇場版白箱" value="10621">劇場版白箱</option>
# <option data-name="老娘就要這麼活" value="10611">老娘就要這麼活</option>
# <option data-name="初戀" value="10607">初戀</option>
# <option data-name="黑暗戰域" value="10606">黑暗戰域</option>
# <option data-name="陪你玩最大" value="10602">陪你玩最大</option>
# <option data-name="觸不到的愛" value="10598">觸不到的愛</option>
# <option data-name="金都" value="10530">金都</option>
# <option data-name="聽教父的話" value="10635">聽教父的話</option>
# <option data-name="監禁100呎" value="10620">監禁100呎</option>
# <option data-name="現屍報" value="10619">現屍報</option>
# <option data-name="壞教育" value="10617">壞教育</option>
# <option data-name="鎖命佈局" value="10616">鎖命佈局</option>
# <option data-name="正在相愛嗎？" value="10615">正在相愛嗎？</option>
# <option data-name="見鬼的戀愛季節" value="10612">見鬼的戀愛季節</option>
# <option data-name="抽屍剝繭" value="10591">抽屍剝繭</option>
# <option data-name="流感" value="10583">流感</option>
# <option data-name="帕華洛帝：世紀男高音" value="10564">帕華洛帝：世紀男高音</option>
# <option data-name="如果我擁抱你請不要害怕" value="10551">如果我擁抱你請不要害怕</option>
# <option data-name="熊熊大作戰" value="10539">熊熊大作戰</option>
# <option data-name="假面騎士令和時代的開端" value="10632">假面騎士令和時代的開端</option>
# <option data-name="日暮" value="10603">日暮</option>
# <option data-name="無聲革命" value="10601">無聲革命</option>
# <option data-name="二階堂家物語" value="10597">二階堂家物語</option>
# <option data-name="惡之華" value="10587">惡之華</option>
# <option data-name="蜈蚣降" value="10586">蜈蚣降</option>
# <option data-name="長沙里之戰：被遺忘的英雄" value="10585">長沙里之戰：被遺忘的英雄</option>
# <option data-name="靈異孤兒院" value="10584">靈異孤兒院</option>
# <option data-name="數碼寶貝 LAST EVOLUTION 絆" value="10572">數碼寶貝 LAST EVOLUTION 絆</option>
# <option data-name="吞噬" value="10560">吞噬</option>
# <option data-name="這一刻，想見你" value="10553">這一刻，想見你</option>
# <option data-name="美好拾光公司" value="10541">美好拾光公司</option>
# <option data-name="緣來想見妳" value="10529">緣來想見妳</option>
# <option data-name="搭火車旅行好吃驚" value="10492">搭火車旅行好吃驚</option>
# <option data-name="海上鋼琴師4K數位修復" value="10613">海上鋼琴師4K數位修復</option>
# <option data-name="浪人47愁錢中" value="10596">浪人47愁錢中</option>
# <option data-name="戀愛倒帶中" value="10589">戀愛倒帶中</option>
# <option data-name="我的粉紅人生" value="10582">我的粉紅人生</option>
# <option data-name="鑰命監獄" value="10579">鑰命監獄</option>
# <option data-name="罪：米開朗基羅" value="10574">罪：米開朗基羅</option>
# <option data-name="居禮夫人：放射永恆" value="10537">居禮夫人：放射永恆</option>
# <option data-name="知道天空有多藍的人啊" value="10526">知道天空有多藍的人啊</option>
# <option data-name="築夢奇蹟" value="10511">築夢奇蹟</option>
# <option data-name="末日異戰" value="10402">末日異戰</option>
# <option data-name="我不流行二十年" value="10614">我不流行二十年</option>
# <option data-name="樂來越愛你" value="10609">樂來越愛你</option>
# <option data-name="搞鬼" value="10570">搞鬼</option>
# <option data-name="政客誠實中" value="10563">政客誠實中</option>
# <option data-name="女聲我最美" value="10528">女聲我最美</option>
# <option data-name="來自深淵 深沉靈魂的黎明" value="10483">來自深淵 深沉靈魂的黎明</option>
# <option data-name="霸王別姬" value="10594">霸王別姬</option>
# <option data-name="阿飛正傳" value="10593">阿飛正傳</option>
# <option data-name="羊男的迷宮" value="10580">羊男的迷宮</option>
# <option data-name="犬鳴村" value="10543">犬鳴村</option>
# <option data-name="間諜速成班" value="10538">間諜速成班</option>
# <option data-name="我的英雄學院劇場版：英雄新世紀" value="10481">我的英雄學院劇場版：英雄新世紀</option>
# <option data-name="魔髮精靈唱遊世界" value="10466">魔髮精靈唱遊世界</option>
# <option data-name="絕命直播" value="10548">絕命直播</option>
# <option data-name="託陰2：布拉姆回來了" value="10540">託陰2：布拉姆回來了</option>
# <option data-name="抓住救命稻草的野獸們" value="10507">抓住救命稻草的野獸們</option>
# <option data-name="Re從零開始的異世界生活 外傳集" value="10480">Re從零開始的異世界生活 外傳集</option>
# <option data-name="刺激1995" value="10518">刺激1995</option>
# <option data-name="劇場版 不起眼女主角培育法 Fine" value="10486">劇場版 不起眼女主角培育法 Fine</option>
# <option data-name="複製柔伊" value="10455">複製柔伊</option>
# <option data-name="練愛iNG" value="10442">練愛iNG</option>
# <option data-name="血衛" value="10469">血衛</option>
# <option data-name="明明會說話" value="10440">明明會說話</option>
# <option data-name="艾瑪" value="10396">艾瑪</option>
# <option data-name="鳴鳥不飛：烏雲密布" value="10458">鳴鳥不飛：烏雲密布</option>
# <option data-name="女鬼橋" value="10437">女鬼橋</option>
# <option data-name="怨咒" value="10421">怨咒</option>
# <option data-name="極地守護犬" value="10383">極地守護犬</option>
# <option data-name="隱形人" value="10359">隱形人</option>
# <option data-name="電影音效傳奇：好萊塢之聲" value="10484">電影音效傳奇：好萊塢之聲</option>
# <option data-name="李察朱威爾事件" value="10368">李察朱威爾事件</option>
# <option data-name="音速小子" value="9246">音速小子</option>
# <option data-name="逃出夢幻島" value="10485">逃出夢幻島</option>
# <option data-name="猛禽小隊：小丑女大解放" value="10268">猛禽小隊：小丑女大解放</option>
# <option data-name="1917" value="10189">1917</option>
# <option data-name="你的情歌" value="10407">你的情歌</option>
# <option data-name="杜立德" value="10316">杜立德</option>
# <option data-name="她們" value="10202">她們</option>
# <option data-name="變身特務" value="9008">變身特務</option>
# <option data-name="巧虎電影：英雄遊樂園" value="10429">巧虎電影：英雄遊樂園</option>
# <option data-name="不完美的正義" value="10243">不完美的正義</option>
# <option data-name="絕地戰警FOR LIFE" value="10242">絕地戰警FOR LIFE</option>
# <option data-name="驅魔直播" value="10375">驅魔直播</option>
# <option data-name="兔嘲男孩" value="10283">兔嘲男孩</option>
# <option data-name="潛艦追緝" value="10333">潛艦追緝</option>
# <option data-name="冰雪奇緣2" value="9597">冰雪奇緣2</option>
# <option data-name="Hello World" value="10302">Hello World</option>
# <option data-name="星際救援" value="10227">星際救援</option>
# <option data-name="駭客任務" value="10088">駭客任務</option>
# <option data-name="幸福綠皮書" value="9150">幸福綠皮書</option>
# <option data-name="魔女首部曲：誕生" value="8817">魔女首部曲：誕生</option>
# <option data-name="道別的早晨就用約定之花點綴吧" value="8292">道別的早晨就用約定之花點綴吧</option>
# <option data-name="不可能的任務：全面瓦解" value="7767">不可能的任務：全面瓦解</option>
# <option data-name="摩天大樓" value="8256">摩天大樓</option>
# <option data-name="噤界" value="7509">噤界</option>
# <option data-name="遊戲人生Zero" value="7546">遊戲人生Zero</option>
# <option data-name="佈局" value="6814">佈局</option>
# <option data-name="玩命關頭8" value="6664">玩命關頭8</option>
# <option data-name="攻敵必救" value="6669">攻敵必救</option>
# <option data-name="鋼鐵英雄" value="6436">鋼鐵英雄</option>
# <option data-name="列車上的女孩" value="6453">列車上的女孩</option>
# <option data-name="碧海藍天" value="6417">碧海藍天</option>
# <option data-name="一首搖滾上月球" value="4887">一首搖滾上月球</option>
# <option data-name="錢不夠用2" value="3026">錢不夠用2</option>
# </select>
# <span>選擇<br/>地區</span>
# <select class="movie_area" id="sbox_aid" name="area_id">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style1-->
# <div class="top_change" data-change="1" style="display:none;">
# <form action="https://movies.yahoo.com.tw/tv_channels.html" id="form_catechannel" method="get" style="display:inline;">
# <span>選擇<br/>分類</span>
# <select class="movie_theater" id="sbox_cid" name="tv_category_id">
# <option value="">請選擇分類</option>
# <option data-name="西片" value="1">西片</option>
# <option data-name="國片" value="2">國片</option>
# <option data-name="戲劇" value="3">戲劇</option>
# <option data-name="體育" value="4">體育</option>
# <option data-name="綜合" value="5">綜合</option>
# <option data-name="知性" value="6">知性</option>
# <option data-name="日本" value="7">日本</option>
# <option data-name="音樂" value="8">音樂</option>
# <option data-name="卡通" value="9">卡通</option>
# <option data-name="新聞" value="10">新聞</option>
# <option data-name="財經" value="11">財經</option>
# <option data-name="宗教" value="12">宗教</option>
# </select>
# <span>選擇<br/>頻道</span>
# <select class="movie_name" id="sbox_chid" name="channel">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
# </form>
# <form action="https://movies.yahoo.com.tw/tvtime_result.html" id="form_channelname" method="get" style="display:inline;">
# <input autocomplete="off" class="tvserch" id="sbox_cname" name="tv_channel_name" onblur="this.placeholder='電視節目查詢'" onfocus="this.placeholder=''" onkeypress="chlSearchForm(event);" placeholder="電視節目查詢" type="text"/>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style2-->
# <div class="top_change" data-change="2" style="display:none;">
# <form action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&amp;campaign_code=yahoopc" id="form_movieticket" method="get">
# <span>選擇<br/>戲院</span>
# <select class="movie_theater" id="sbox_tid" name="cinemaId">
# <option value="">請選擇戲院</option>
# <option value="40288eb0050f542401050f554e7e0674">台北信義威秀影城</option>
# <option value="f644412efbb811e58858f2128151146f">台北真善美劇院</option>
# <option value="470e99e70b5611eaa91e06ba2bcebcfa">MUVIE CINEMAS台北松仁威秀</option>
# <option value="46efa950eafa11e38b12987bdb90dba4">台北樂聲影城</option>
# <option value="e9c365f27f4e11e494ae8b4ddf78b93a">台北in89豪華數位影城</option>
# <option value="4c163aba9c5311e494ae8b4ddf78b93a">台北新民生戲院</option>
# <option value="40288eb0050f542401050f5550201811">哈拉影城</option>
# <option value="40288eb0050f542401050f5681782dc5">喜樂時代影城南港店</option>
# <option value="40288eb0050f542401050f5566201ba4">台北華威天母影城</option>
# <option value="5f60dacd-45b3-102d-8d74-e400529c">台北京站威秀影城</option>
# <option value="40288eb0050f542401050f551a8a48c3">台北日新威秀影城</option>
# <option value="b020ba50fbc811e58858f2128151146f">梅花數位影院</option>
# <option value="40288eb0050f542401050f55532606b5">喜滿客絕色影城</option>
# <option value="cf2b5aa8132f11e6b767a1b123456789">台北新光影城</option>
# <option value="40288eb0050f31210ada0f55676b1bbc">台北美麗華大直影城</option>
# <option value="737ece862a0111e18e86000bdb90dba4">板橋大遠百威秀影城</option>
# <option value="73544d843cd311e69bb83d0f96c001c2">林口MITSUI OUTLET PARK威秀影城</option>
# <option value="c072c5c43fc011e9a245782bcb259cad">喜樂時代影城永和店</option>
# <option value="5d4b59f567ac11e7a6b1061be09fe071">桃園in89統領影城</option>
# <option value="c256b670b10811e8959e782bcb259cad">桃園統領威秀影城</option>
# <option value="40288eb0050f542401050f5573651ca2">新竹大遠百威秀影城</option>
# <option value="4f9fbbac7a2d11e18e86000bdb90dba4">新竹巨城威秀影城</option>
# <option value="883ddebefe9e11e49e5e8d16c6a1d23a">頭份尚順威秀影城</option>
# <option value="40288eb0050f542401050f5576601cdc">台中Tiger City威秀影城</option>
# <option value="7ff29bea908122e9060e893bcb360cad">台中豐原in89豪華影城</option>
# <option value="9f1b3df8f0a44110ab9412513c546d33">台中新時代凱擘影城</option>
# <option value="84599c0a220d11e18e86000bdb90dba4">台中大遠百威秀影城</option>
# <option value="5307fea6405811e392f7000bdb90dba4">台中華威台中影城</option>
# <option value="9fa318f9c99f4f6987a46efc5e3f50f2">台中新光影城</option>
# <option value="40288eb0050f542401050f557dfc1d65">台南大遠百威秀影城</option>
# <option value="370b0003943222e8a7b2172be10fe182">台南FOCUS威秀影城</option>
# <option value="c3ab0cdc8cad11e494ae8b4ddf78b93a">台南南紡威秀影城</option>
# <option value="5d4b59f597ac11e7a6b1091be09fe001">台南真善美劇院</option>
# <option value="a6f9c512bec5463183d3d7eaec37fb42">台南新光影城</option>
# <option value="40288eb0050f542401050f5582141dac">高雄大遠百威秀影城</option>
# <option value="44f76448bf2511e59a5d4b53bcb866d6">高雄in89駁二電影院</option>
# <option value="40288eb0050f542401050f5581582dc5">喜滿客夢時代影城</option>
# <option value="2c28121ae2c711e292f7000bdb90dba4">中影屏東影城</option>
# <option value="e8bf57d61edb11e9a245782bcb259cad">花蓮新天堂樂園威秀影城</option>
# <option value="6ff18bea897011e8959e782bcb259cad">澎湖in89豪華影城</option>
# </select>
# <span>選擇<br/>片名</span>
# <select class="movie_name" id="sbox_tmid" name="movieId">
# </select>
# <span>選擇<br/>日期</span>
# <select class="movie_day" name="showDate">
# </select>
# <span>選擇<br/>場次</span>
# <select class="movie_screenings" name="session">
# </select>
# <span>選擇<br/>數量</span>
# <select class="movie_amount" name="ticketQuantity">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']" data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style3-->
# <div class="top_change" data-change="3" style="display:none;">
# <form action="https://movies.yahoo.com.tw/moviesearch_result.html" id="form_starsearch" method="get">
# <input autocomplete="off" class="starserch" id="starserch" name="keyword" onblur="this.placeholder='電影/ 明星搜尋'" onfocus="this.placeholder=''" placeholder="電影 / 明星搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden">
# </div>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']" data-input="['input','starserch','']">查詢</div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="content _c" id="container">
# <div id="content_r">
# <!--AD 300X250-->
# <!-- if $exist diff with 0 will removed from module section -->
# <div class="top_ad_300_250 r_box" data-ad="LREC" id="boxLREC">
# </div>
# <!--AD 300X100-->
# <div class="ad_300_250 r_box" data-ad="NP1" id="boxNP1">
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             電影排行榜
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="tabbox_btn_r">
# <li class="select" data-id="list1">台北票房榜</li>
# <li data-id="list2">全美票房榜</li>
# <li data-id="list3">預告片榜</li>
# </ul>
# <div class="ranking_inner_r">
# <div class="tab-content">
# <div class="tab-pane" id="list1">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','數碼寶貝 LAST EVOLUTION 絆']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%95%B8%E7%A2%BC%E5%AF%B6%E8%B2%9D-LAST-EVOLUTION-%E7%B5%86-digimon-adventure-last-evolution-kizuna-10572"><img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/March2020/hpmCQ2W3sG3NPg6n81oh-493x720.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','數碼寶貝 LAST EVOLUTION 絆']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%95%B8%E7%A2%BC%E5%AF%B6%E8%B2%9D-LAST-EVOLUTION-%E7%B5%86-digimon-adventure-last-evolution-kizuna-10572">
#                   數碼寶貝 LAST EVOLUTION 絆</a>
# <span class="text_truncate_4 text_truncate_dot"><p>成為大學生的太一及亞古獸各自步上了屬於自己的道路。某天，在專門研究研究數碼寶貝的專家梅諾雅的告知下，太一等人得知了當被選上的孩子們逐漸長大成人之際，過去伴隨著他們冒險的數碼寶貝們，也將隨著時間消逝，而戰鬥則可能會加速與他們別離的時間...…就在此時，全世界被選上的孩子們周遭發生了異變，而太一等人也陷入了苦惱之中…</p>
# <p> </p>
# <p>《數碼寶貝》系列 20 週年的紀念作品，太一與亞古獸最終的物語，就此展開！</p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','數碼寶貝 LAST EVOLUTION 絆']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%95%B8%E7%A2%BC%E5%AF%B6%E8%B2%9D-LAST-EVOLUTION-%E7%B5%86-digimon-adventure-last-evolution-kizuna-10572">
# <li class="select">
# <div class="num">1</div>
# <span>數碼寶貝 LAST EVOLUTION 絆</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','壞教育']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E6%95%99%E8%82%B2-bad-education-10617">
# <li class="">
# <div class="num">2</div>
# <span>壞教育</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','黑暗戰域']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E6%9A%97%E6%88%B0%E5%9F%9F-the-blackout-10606">
# <li class="">
# <div class="num">3</div>
# <span>黑暗戰域</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','鎖命佈局']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%8E%96%E5%91%BD%E4%BD%88%E5%B1%80-inheritance-10616">
# <li class="">
# <div class="num">4</div>
# <span>鎖命佈局</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','劇場版 白箱']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8A%87%E5%A0%B4%E7%89%88%E7%99%BD%E7%AE%B1-shirobako-the-movie-10621">
# <li class="">
# <div class="num">5</div>
# <span>劇場版 白箱</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','見鬼的戀愛季節']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A6%8B%E9%AC%BC%E7%9A%84%E6%88%80%E6%84%9B%E5%AD%A3%E7%AF%80-low-season-10612">
# <li class="">
# <div class="num">6</div>
# <span>見鬼的戀愛季節</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','抽屍剝繭']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%8A%BD%E5%B1%8D%E5%89%9D%E7%B9%AD-cut-off-10591">
# <li class="">
# <div class="num">7</div>
# <span>抽屍剝繭</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','美好拾光公司']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BE%8E%E5%A5%BD%E6%8B%BE%E5%85%89%E5%85%AC%E5%8F%B8-la-belle-epoque-10541">
# <li class="">
# <div class="num">8</div>
# <span>美好拾光公司</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','金都']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%87%91%E9%83%BD-my-prince-edward-10530">
# <li class="">
# <div class="num">9</div>
# <span>金都</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','流感']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E6%84%9F-the-flu-10583">
# <li class="">
# <div class="num">10</div>
# <span>流感</span>
# </li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2020-05-09~2020-05-10</div>
# </div>
# <div class="tab-pane" id="list2">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/May2020/X6Z0vBj3B6xWFurAhMlX-1280x1827.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
#                   1/2的魔法</a>
# <span class="text_truncate_4 text_truncate_dot"><p>《1/2的魔法》故事背景在現代科技已比精通魔法還方便的精靈世界，精靈、人馬、美人魚、獨角獸、小龍等魔法生物都生活在現代化社區裡，過著與你我無異的「沒有魔法的生活」。由湯姆霍蘭與克里普瑞特所配音的精靈兄弟們，很小的時後便失去了父親，但在弟弟的16歲生日這天，他收到了一個很特別的禮物- 他父親從前的魔杖以及一串魔咒，可以讓爸爸起死回生，但年久失修的魔法技能，讓施魔法時出了差錯，爸爸只剩一雙腿，於是兄弟倆踏上尋找魔法石的征途，最後能否順利讓爸爸「完璧」歸來呢? </p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
# <li class="select">
# <div class="num">1</div>
# <span>1/2的魔法</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','血衛']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A1%80%E8%A1%9B-bloodshot-10469">
# <li class="">
# <div class="num">2</div>
# <span>血衛</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','依然相信']" href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%9D%E7%84%B6%E7%9B%B8%E4%BF%A1-i-still-believe-10487">
# <li class="">
# <div class="num">3</div>
# <span>依然相信</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','隱形人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9A%B1%E5%BD%A2%E4%BA%BA-the-invisible-man-10359">
# <li class="">
# <div class="num">4</div>
# <span>隱形人</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">5</div>
# <span>The Hunt</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','音速小子']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9F%B3%E9%80%9F%E5%B0%8F%E5%AD%90-sonic-the-hedgehog-9246">
# <li class="">
# <div class="num">6</div>
# <span>音速小子</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">7</div>
# <span>The Way Back</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','極地守護犬']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%A5%B5%E5%9C%B0%E5%AE%88%E8%AD%B7%E7%8A%AC-the-call-of-the-wild-10383">
# <li class="">
# <div class="num">8</div>
# <span>極地守護犬</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','艾瑪']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%89%BE%E7%91%AA-emma-10396">
# <li class="">
# <div class="num">9</div>
# <span>艾瑪</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','絕地戰警FOR LIFE']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%9C%B0%E6%88%B0%E8%AD%A6FOR-LIFE-bad-boys-for-life-10242">
# <li class="">
# <div class="num">10</div>
# <span>絕地戰警FOR LIFE</span>
# </li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2020-03-13~2020-03-15</div>
# </div>
# <div class="tab-pane" id="list3">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','壞教育']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E6%95%99%E8%82%B2-bad-education-10617"><img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/April2020/S7LwnMQvUlamRn5BYO0j-1280x1829.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','壞教育']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E6%95%99%E8%82%B2-bad-education-10617">
#                     壞教育</a>
# <span class="text_truncate_4 text_truncate_dot"><p>★ 震驚美國教育界史上最大校園騙局案改編</p>
# <p>★《大娛樂家》休傑克曼、艾莉森珍妮金獎卡司同台飆戲！  </p>
# <p>★「休傑克曼演技再創巔峰，大師級精湛演出！」－權威媒體〈Variety〉</p>
# <p>★「艾莉森珍妮生涯最精彩演出」－權威媒體〈Variety〉</p>
# <p>★ 權威影評網站爛蕃茄89%、imdb7.3高分推薦，口碑爆棚！</p>
# <p>★ 第44屆多倫多影展「特別放映單元」入選片！</p>
# <p> </p>
# <p>貪得無厭 才能學無止境！</p>
# <p> </p>
# <p>在教育界享負盛名的法蘭克塔松(休傑克曼飾)是個對教育充滿熱忱、魅力十足的學區負責人，在他和同事潘葛拉肯(艾莉森珍妮飾)的帶領之下，紐約羅斯林學區升學率在全美排名第四，他們的目標是成為全美第一的頂尖學區。飆升的大學錄取率帶動了房價與社區發展，法蘭克的貢獻也聲名遠播。直到某天，羅斯林高中的學生瑞秋(潔芮汀薇思瓦納森飾)在撰寫學校建案的校刊報導時，無意間發現了校內帳目出現各種錯誤，在她的調查下慢慢揭開了法蘭克「為人師婊」的真面目，也讓長達逾十年、攸關數百萬美元的美國史上最大校園弊案浮上檯面…</p>
# <p> </p>
# <p>【關於電影】</p>
# <p> </p>
# <p>震驚全美史上最大校園詐騙案　休傑克曼「雙面演技」轟動全球！</p>
# <p>集結好萊塢巨星休傑克曼、奧斯卡最佳女配角艾莉森珍妮與喜劇天王雷羅曼諾首度同台飆戲，電影《壞教育》在2019年於多倫多影展舉辦世界首映口碑席捲全球，權威外媒〈Variety〉、〈The Hollywood Reporter〉、〈Indiewire〉、〈Vanityfair〉、〈The Playlist〉、〈The Film stage〉一致盛讚，休傑克曼在片中詮釋充滿熱忱與魅力的完美形象與身陷醜聞的複雜人性，亦正亦邪的雙面演技更被譽為是「從影以來最顛覆演出！」</p>
# <p> </p>
# <p>《壞教育》是編劇麥克馬克斯基依據自己高中時期的真實經歷啟發而創作成電影劇本，將十年前震驚全美的羅斯林高中醜聞搬上大銀幕，更曾被列進2016年的好萊塢劇本黑名單。導演柯瑞芬利表示他的親友是公立與私立學校的教師，而他自己也曾擔任家教，他坦言：「美國的教育制度非常複雜，它深深影響著經濟與階級，教育體系牽動了整個社區發展。」因此當年有望在全美黃金學區中奪冠的羅斯林學區傳出醜聞後震驚全國，編劇麥克馬可斯更感慨表示曾在小時候見過法蘭克本人，是一個風度翩翩、魅力十足的好人，他說：「他永遠說著激勵學童的話語，讓每個學生深信自己有能力實現夢想，他對教育的熱忱毋庸置疑，因此當事件爆發後，完全顛覆了他在我心裡的樣子。」</p>
# <p> </p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','壞教育']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E6%95%99%E8%82%B2-bad-education-10617">
# <li class="select">
# <div class="num">1</div>
# <span>壞教育</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','初戀']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%88%9D%E6%88%80-first-love-10607">
# <li class="">
# <div class="num">2</div>
# <span>初戀</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','海邊走走']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%B7%E9%82%8A%E8%B5%B0%E8%B5%B0-hope-gap-10495">
# <li class="">
# <div class="num">3</div>
# <span>海邊走走</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','金都']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%87%91%E9%83%BD-my-prince-edward-10530">
# <li class="">
# <div class="num">4</div>
# <span>金都</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','流感']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E6%84%9F-the-flu-10583">
# <li class="">
# <div class="num">5</div>
# <span>流感</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','靠北少女']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9D%A0%E5%8C%97%E5%B0%91%E5%A5%B3-not-quite-dead-yet-10575">
# <li class="">
# <div class="num">6</div>
# <span>靠北少女</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','鎖命佈局']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%8E%96%E5%91%BD%E4%BD%88%E5%B1%80-inheritance-10616">
# <li class="">
# <div class="num">7</div>
# <span>鎖命佈局</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','見鬼的戀愛季節']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A6%8B%E9%AC%BC%E7%9A%84%E6%88%80%E6%84%9B%E5%AD%A3%E7%AF%80-low-season-10612">
# <li class="">
# <div class="num">8</div>
# <span>見鬼的戀愛季節</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','素人特工']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B4%A0%E4%BA%BA%E7%89%B9%E5%B7%A5-the-rookies-10622">
# <li class="">
# <div class="num">9</div>
# <span>素人特工</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','抽屍剝繭']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%8A%BD%E5%B1%8D%E5%89%9D%E7%B9%AD-cut-off-10591">
# <li class="">
# <div class="num">10</div>
# <span>抽屍剝繭</span></li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2020-05-14</div>
# </div>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
# <div class="plus"></div>看更多
#         </a>
# </div>
# </div>
# </div>
# </div>
# <!--懶人卡-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             懶人卡
#         </span>
# </div>
# <div class="r_box_inner">
# <div class="lazy_card_r">
# <dl>
# <dt>
# <div class="lazy_card_inner_r">
# <a class="gabtn" data-ga="['懶人卡','','']" href="https://tw.youcard.yahoo.com/cardstack/27980750-95b7-11ea-a05f-6b3c38df5489" target="_blank">
# <div class="foto">
# <img alt="" src="https://pbs.twimg.com/media/EXuF7ooU8Acf5Pw.jpg"/>
# </div>
# <div class="lazy_card_info_r">
# <div class="lazy_txt">
#                       台日友好！在戲劇裡看得到！
#                     </div>
# <span>雀雀</span>
# </div>
# </a>
# </div>
# </dt>
# <dd>
# <div class="lazy_card_inner_r">
# <a class="gabtn" data-ga="['懶人卡','','']" href="https://tw.youcard.yahoo.com/cardstack/ba73aaf0-95a0-11ea-a05f-6b3c38df5489" target="_blank">
# <div class="foto">
# <img alt="" src="https://www.jozefsquare.com/wp-content/uploads/2018/04/Zdenek-Vlach-The-Last-Emperor-1988-copy.jpg"/>
# </div>
# <div class="lazy_card_info_r">
# <div class="lazy_txt">
#                       丟掉歷史課本,看電影來學清末民初到建國的中國史！
#                     </div>
# <span>雀雀</span>
# </div>
# </a>
# </div>
# </dd>
# </dl>
# </div>
# <div class="btn_plus_more">
# <a class="gabtn" data-ga="['懶人卡','懶人卡_看更多','']" href="https://tw.youcard.yahoo.com/category/movie" target="_blank">
# <div class="plus"></div>
#         看更多
#       </a>
# </div>
# </div>
# </div>
# <!--AD 300X250-->
# <div class="ad_300_250 r_box" data-ad="LREC3" id="boxLREC3">
# <div id="tgtLREC3"></div>
# </div>
# <!--FB-->
# <div class="fb r_box">
# </div>
# <!--你最近瀏覽的電影-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             你最近瀏覽的電影
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="recently_viewed">
# </ul>
# </div>
# </div>
# <div></div>
# </div>
# <div id="content_l">
# <!--電影資訊-->
# <div class="l_box have_arbox kvbox">
# <div class="movie_tab">
# <ul class="movie_tab_list">
# <li class="">
# <a href="javascript:void(0)">最新電影</a>
# </li>
# <li class="select">
# <a href="javascript:void(0)">編輯推薦</a>
# </li>
# </ul>
# <dl class="title_btnbox _appendarr"></dl> </div>
# <div class="l_box_inner_content">
# <div class="l_box_inner" data-module="0">
# <ul class="movie_ind_list">
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/February2020/gdYjSDCbhps7vxkQ9T0K-504x720.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%B7%E9%82%8A%E8%B5%B0%E8%B5%B0-hope-gap-10495"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/video/%E6%B5%B7%E9%82%8A%E8%B5%B0%E8%B5%B0-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-134342535.html?movie_id=10495"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10495"><span>時  刻  表</span></a>
# </div>
# </div>
# </div>
# <div class="movielist_info_inner">
# <div class="movielist_info">
# <h2>
# <a class="gabtn text_truncate_1" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%B7%E9%82%8A%E8%B5%B0%E8%B5%B0-hope-gap-10495">海邊走走</a>
# </h2>
# <h3>上映日期：5 月 15 日</h3>
# <div class="appraise starwithnum">
# <div class="percent"><p>期待度：</p><span>69%</span></div>
# </div>
# </div>
# <div class="movielist_btn color_btnbox">
# <a class="btn_s_vedio gabtn" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/video/%E6%B5%B7%E9%82%8A%E8%B5%B0%E8%B5%B0-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-134342535.html?movie_id=10495">預告片</a>
# <a class="btn_s_time gabtn" data-ga="['最新電影','最新電影_電影1','海邊走走']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10495">時刻表</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/May2020/jDbt2Odzc4yqNNHQ5Fdp-1280x1822.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A5%AA%E5%91%BD%E9%9A%A7%E9%81%93-the-tunnel-10599"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/video/%E5%A5%AA%E5%91%BD%E9%9A%A7%E9%81%93-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-132502878.html?movie_id=10599"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10599"><span>時  刻  表</span></a>
# </div>
# </div>
# </div>
# <div class="movielist_info_inner">
# <div class="movielist_info">
# <h2>
# <a class="gabtn text_truncate_1" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A5%AA%E5%91%BD%E9%9A%A7%E9%81%93-the-tunnel-10599">奪命隧道</a>
# </h2>
# <h3>上映日期：5 月 15 日</h3>
# <div class="appraise starwithnum">
# <div class="percent"><p>期待度：</p><span>91%</span></div>
# </div>
# </div>
# <div class="movielist_btn color_btnbox">
# <a class="btn_s_vedio gabtn" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/video/%E5%A5%AA%E5%91%BD%E9%9A%A7%E9%81%93-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-132502878.html?movie_id=10599">預告片</a>
# <a class="btn_s_time gabtn" data-ga="['最新電影','最新電影_電影2','奪命隧道']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10599">時刻表</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/April2020/oS8g98YnFMxGA5OeHYD2-500x714.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A5%87%E8%B9%9F%E6%95%91%E6%8F%B4-the-cave-10605"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/video/%E5%A5%87%E8%B9%9F%E6%95%91%E6%8F%B4-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-150540823.html?movie_id=10605"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10605"><span>時  刻  表</span></a>
# </div>
# </div>
# </div>
# <div class="movielist_info_inner">
# <div class="movielist_info">
# <h2>
# <a class="gabtn text_truncate_1" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A5%87%E8%B9%9F%E6%95%91%E6%8F%B4-the-cave-10605">奇蹟救援</a>
# </h2>
# <h3>上映日期：5 月 15 日</h3>
# <div class="appraise starwithnum">
# <div class="percent"><p>期待度：</p><span>96%</span></div>
# </div>
# </div>
# <div class="movielist_btn color_btnbox">
# <a class="btn_s_vedio gabtn" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/video/%E5%A5%87%E8%B9%9F%E6%95%91%E6%8F%B4-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-150540823.html?movie_id=10605">預告片</a>
# <a class="btn_s_time gabtn" data-ga="['最新電影','最新電影_電影3','奇蹟救援']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10605">時刻表</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/April2020/qcH1eFSMRVzgAQf6xa3T-504x720.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影4','誰殺了唐吉訶德']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%AA%B0%E6%AE%BA%E4%BA%86%E5%94%90%E5%90%89%E8%A8%B6%E5%BE%B7-the-man-who-killed-don-quixote-10624"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv noselect">
# <a href="javascript:void(0)"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影4','誰殺了唐吉訶德']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10624"><span>時  刻  表</span></a>
# </div>
# </div>
# </div>
# <div class="movielist_info_inner">
# <div class="movielist_info">
# <h2>
# <a class="gabtn text_truncate_1" data-ga="['最新電影','最新電影_電影4','誰殺了唐吉訶德']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%AA%B0%E6%AE%BA%E4%BA%86%E5%94%90%E5%90%89%E8%A8%B6%E5%BE%B7-the-man-who-killed-don-quixote-10624">誰殺了唐吉訶德</a>
# </h2>
# <h3>上映日期：5 月 15 日</h3>
# <div class="appraise starwithnum">
# <div class="percent"><p>期待度：</p><span>88%</span></div>
# </div>
# </div>
# <div class="movielist_btn color_btnbox">
# <a class="btn_s_vedio no_select" href="javascript:void(0)">預告片</a>
# <a class="btn_s_time gabtn" data-ga="['最新電影','最新電影_電影4','誰殺了唐吉訶德']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10624">時刻表</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/May2020/SMHE3jCPq73ckeFiowDf-800x1143.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%99%BD%E9%AB%AE%E9%AD%94%E5%A5%B3%E5%82%B3-the-bride-with-white-hair-10639"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/video/%E7%99%BD%E9%AB%AE%E9%AD%94%E5%A5%B3%E5%82%B3-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-055228769.html?movie_id=10639"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10639"><span>時  刻  表</span></a>
# </div>
# </div>
# </div>
# <div class="movielist_info_inner">
# <div class="movielist_info">
# <h2>
# <a class="gabtn text_truncate_1" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%99%BD%E9%AB%AE%E9%AD%94%E5%A5%B3%E5%82%B3-the-bride-with-white-hair-10639">白髮魔女傳</a>
# </h2>
# <h3>上映日期：5 月 15 日</h3>
# <div class="appraise starwithnum">
# <div class="percent"><p>期待度：</p><span>95%</span></div>
# </div>
# </div>
# <div class="movielist_btn color_btnbox">
# <a class="btn_s_vedio gabtn" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/video/%E7%99%BD%E9%AB%AE%E9%AD%94%E5%A5%B3%E5%82%B3-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-055228769.html?movie_id=10639">預告片</a>
# <a class="btn_s_time gabtn" data-ga="['最新電影','最新電影_電影5','白髮魔女傳']" href="https://movies.yahoo.com.tw/movietime_result.html/id=10639">時刻表</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="_slickcontent">
# <div class="movie_foto">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/April2020/wkis1C1ChQsNIDS0hUv7-504x720.jpg"/>
# <div class="movie_ovrbox">
# <div class="ovr_btn_info">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影6','末代皇帝']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%9C%AB%E4%BB%A3%E7%9A%87%E5%B8%9D-the-last-emperor-10640"><span>電影介紹</span></a>
# </div>
# <div class="ovr_btn_mv">
# <a class="gabtn" data-ga="['最新電影','最新電影_電影6','末代皇帝']" href="https://movies.yahoo.com.tw/video/%E6%9C%AB%E4%BB%A3%E7%9A%87%E5%B8%9D-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-053031648.html?movie_id=10640"><span>預  告  片</span></a>
# </div>
# <div class="ovr_btn_mv">
# ...
# <div class="news_content">
# <div class="foto">
# <div class="fotoinner">
# <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/kHTex7nheK.RwaKU5DFdsg--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xODAwO2g9MTIwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-05/49f01e30-95af-11ea-9ff4-89b323205fbc"/>
# </div>
# </div>
# <div class="info_box">
# <h2 class="text_truncate_2">哥雅獎男星製毒發大財  《放飛大丈夫》蟬連西班牙雙週票房冠軍</h2>
# <span class="jq_text_overflow_120 jq_text_overflow_link">
#                           創下西班牙年度票房奇蹟的超ㄎㄧㄤ喜劇《放飛大丈夫》（I Can Quit Whenever I Want），不僅蟬連西班牙雙週票房冠軍，更吸引近200萬觀影人次，最後熱賣突破3.7億台幣票房，讓人咋舌這部「白天當老師，晚上當毒師」的犯罪喜劇吸金魅力！
#                       </span>
# <div class="day">2020-05-14</div>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['情報站','情報站_文章3','托爾比約恩 為《奪命隧道》受訓一個月 展現救難人員勇敢、犧牲奉獻與無私的精神']" href="https://movies.yahoo.com.tw/article/%E6%89%98%E7%88%BE%E6%AF%94%E7%B4%84%E6%81%A9-%E7%82%BA%E5%A5%AA%E5%91%BD%E9%9A%A7%E9%81%93%E5%8F%97%E8%A8%93%E4%B8%80%E5%80%8B%E6%9C%88-%E5%B1%95%E7%8F%BE%E6%95%91%E9%9B%A3%E4%BA%BA%E5%93%A1%E5%8B%87%E6%95%A2%E7%8A%A7%E7%89%B2%E5%A5%89%E7%8D%BB%E8%88%87%E7%84%A1%E7%A7%81%E7%9A%84%E7%B2%BE%E7%A5%9E-064715662.html">
# <div class="news_content">
# <div class="foto">
# <div class="fotoinner">
# <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/lNskAtQmiStv1G0.fkYK8g--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz00MDk2O2g9MTcxNjs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-05/4b7c31e0-95ae-11ea-beff-7f9d1cd2edc3"/>
# </div>
# </div>
# <div class="info_box">
# <h2 class="text_truncate_2">托爾比約恩 為《奪命隧道》受訓一個月 展現救難人員勇敢、犧牲奉獻與無私的精神</h2>
# <span class="jq_text_overflow_120 jq_text_overflow_link">
#                           望著從隧道口冒出來的陣陣濃煙，在《奪命隧道》(THE TUNNEL)中飾演王牌救難隊員史丹的托爾比約恩哈爾(Thorbjørn Harr)，在顧問的指導下，穿戴好全副救難裝備，等待導演一聲令下，即刻要駕車駛入伸手不見五指的火場隧道中，他說：「儘管知道安全裝備絕對足夠，消防人員也在一旁待命，但是看見消防顧問嚴肅的神情，心情上依舊如臨大敵。」
#                       </span>
# <div class="day">2020-05-14</div>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['情報站','情報站_文章4','永遠的巨星張國榮愛情武俠代表作《白髮魔女傳》  「靚絕五台山」藍潔瑛展現惡女演技']" href="https://movies.yahoo.com.tw/article/%E6%B0%B8%E9%81%A0%E7%9A%84%E5%B7%A8%E6%98%9F%E5%BC%B5%E5%9C%8B%E6%A6%AE%E6%84%9B%E6%83%85%E6%AD%A6%E4%BF%A0%E4%BB%A3%E8%A1%A8%E4%BD%9C%E7%99%BD%E9%AB%AE%E9%AD%94%E5%A5%B3%E5%82%B3-%E9%9D%9A%E7%B5%95%E4%BA%94%E5%8F%B0%E5%B1%B1%E8%97%8D%E6%BD%94%E7%91%9B%E5%B1%95%E7%8F%BE%E6%83%A1%E5%A5%B3%E6%BC%94%E6%8A%80-064120977.html">
# <div class="news_content">
# <div class="foto">
# <div class="fotoinner">
# <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/CSO85TrVZbEVydtWpxo9Mg--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xMDY2O2g9NzIwOw--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-05/3ff7b2a1-95ad-11ea-9fff-84ba4eb38f6a"/>
# </div>
# </div>
# <div class="info_box">
# <h2 class="text_truncate_2">永遠的巨星張國榮愛情武俠代表作《白髮魔女傳》  「靚絕五台山」藍潔瑛展現惡女演技</h2>
# <span class="jq_text_overflow_120 jq_text_overflow_link">
#                           永遠的巨星張國榮儘管已經離開了17年，但是喜歡他的影迷們每一年都會在有關他的任何特別節日紀念他，17年來從不間斷。他過往演出的經典愛情代表作品《夜半歌聲》及《白髮魔女傳》於今年完成4K數位修復。《白髮魔女傳》中除了張國榮與林青霞這對經典CP，也看到另一位影帝級演員吳鎮宇和「靚絕五台山」已逝演員藍潔瑛的精彩演出。
#                       </span>
# <div class="day">2020-05-14</div>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['情報站','情報站_文章5','台北101現身Netflix海報爆熱議   文湖線竟成《末日列車》']" href="https://movies.yahoo.com.tw/article/%E5%8F%B0%E5%8C%97-101-%E7%8F%BE%E8%BA%AB-netflix%E6%B5%B7%E5%A0%B1%E7%88%86%E7%86%B1%E8%AD%B0-%E6%96%87%E6%B9%96%E7%B7%9A%E7%AB%9F%E6%88%90%E6%9C%AB%E6%97%A5%E5%88%97%E8%BB%8A-054500815.html">
# <div class="news_content">
# <div class="foto">
# <div class="fotoinner">
# <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/LCKs9CF1UGmAg8CtYx3apQ--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MjIyMjs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-05/cc4c5070-95a4-11ea-bb71-f0354d9d83eb"/>
# </div>
# </div>
# <div class="info_box">
# <h2 class="text_truncate_2">台北101現身Netflix海報爆熱議   文湖線竟成《末日列車》</h2>
# <span class="jq_text_overflow_120 jq_text_overflow_link">
#                           Netflix今天發布(5/14)影迷期待已久的科幻驚悚影集《末日列車》(Snowpiercer) 正式預告。本片以《寄生上流》榮獲奧斯卡金像獎最佳導演奉俊昊的同名電影改編，延伸末日警世寓言，發展成十集的全新故事。由韓國名導朴贊郁、奉俊昊聯手監製
#                       </span>
# <div class="day">2020-05-14</div>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="btn_plus_more gabtn">
# <a class="gabtn" data-ga="['情報站','情報站_看更多','']" href="https://movies.yahoo.com.tw/article_index.html">
# <div class="plus"></div>
#           看更多
#           </a>
# </div>
# </div>
# <!--精采圖片-->
# <div class="l_box have_arbox _c">
# <div class="title">
# <span>
#                 精彩圖片
#             </span>
# <dl class="title_btnbox _appendarr"></dl> </div>
# <div class="l_box_inner">
# <ul class="featured_img imglist">
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片1','防範疫情！30張保持社交距離的電影海報']" href="https://movies.yahoo.com.tw/slideshow/%E9%98%B2%E7%AF%84%E7%96%AB%E6%83%85-30-%E5%BC%B5%E4%BF%9D%E6%8C%81%E7%A4%BE%E4%BA%A4%E8%B7%9D%E9%9B%A2%E7%9A%84%E9%9B%BB%E5%BD%B1%E6%B5%B7%E5%A0%B1-155121079.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/vSlFM8nnstuMkqk_7XfkUw--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz02NzU7aD0xMDAwOw--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-04/8e758010-7b40-11ea-affb-3dc472efca65"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         防範疫情！30張保持社交距離的電影海報
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片2','延檔潮襲來！《血衛》成近期最盛大紅毯']" href="https://movies.yahoo.com.tw/slideshow/%E5%BB%B6%E6%AA%94%E6%BD%AE%E8%A5%B2%E4%BE%86%E8%A1%80%E8%A1%9B%E6%88%90%E8%BF%91%E6%9C%9F%E6%9C%80%E7%9B%9B%E5%A4%A7%E7%B4%85%E6%AF%AF-032343934.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/v9On_vf9plbtoS6FbE4Yyg--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MTAwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-03/471da260-67fe-11ea-8ebf-e9a451f5994a"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         延檔潮襲來！《血衛》成近期最盛大紅毯
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片3','IMDb精選！《寄生上流》粉絲應該也愛的12部電影']" href="https://movies.yahoo.com.tw/slideshow/im-db%E7%B2%BE%E9%81%B8%E5%AF%84%E7%94%9F%E4%B8%8A%E6%B5%81%E7%B2%89%E7%B5%B2%E6%87%89%E8%A9%B2%E4%B9%9F%E6%84%9B%E7%9A%84-12-%E9%83%A8%E9%9B%BB%E5%BD%B1-223158513.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/7gCfnBtMDDkFRHOCmC0adw--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz01OTc7aD0zOTg7/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/71cfed50-5b43-11ea-bfe5-804313a97fc8"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         IMDb精選！《寄生上流》粉絲應該也愛的12部電影
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片4','圖多有鬼！心臟夠強才能看的最新恐怖片單']" href="https://movies.yahoo.com.tw/slideshow/%E5%9C%96%E5%A4%9A%E6%9C%89%E9%AC%BC%E5%BF%83%E8%87%9F%E5%A4%A0%E5%BC%B7%E6%89%8D%E8%83%BD%E7%9C%8B%E7%9A%84%E6%9C%80%E6%96%B0%E6%81%90%E6%80%96%E7%89%87%E5%96%AE-231558617.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/WW_7grv53TOUV9p7lTELMA--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz02MDA7aD00MDA7/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/bfda0130-575a-11ea-bb76-01da98388aaf"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         圖多有鬼！心臟夠強才能看的最新恐怖片單
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片5','別出心裁！藝術家精心設計奧斯卡小金人海報']" href="https://movies.yahoo.com.tw/slideshow/%E5%88%A5%E5%87%BA%E5%BF%83%E8%A3%81%E8%97%9D%E8%A1%93%E5%AE%B6%E7%B2%BE%E5%BF%83%E8%A8%AD%E8%A8%88%E5%A5%A7%E6%96%AF%E5%8D%A1%E5%B0%8F%E9%87%91%E4%BA%BA%E6%B5%B7%E5%A0%B1-024015275.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/jJZLb8wDv.uJSy_1H2mWBQ--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MTUwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/47d86c60-4bae-11ea-b91e-a878f8435ba6"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         別出心裁！藝術家精心設計奧斯卡小金人海報
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片6','賀新年！迪士尼釋出春節版新片海報']" href="https://movies.yahoo.com.tw/slideshow/%E8%B3%80%E6%96%B0%E5%B9%B4%E8%BF%AA%E5%A3%AB%E5%B0%BC%E9%87%8B%E5%87%BA%E6%98%A5%E7%AF%80%E7%89%88%E6%96%B0%E7%89%87%E6%B5%B7%E5%A0%B1-210955962.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/1JacKdtfKDSMLN6hOBwwgA--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz04MDA7aD0xNDU3Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-01/0dfa3f50-4212-11ea-bfed-5be09f0f1dc5"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         賀新年！迪士尼釋出春節版新片海報
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片7','【Yahoo年度十大】年度最嚇！2019十大驚悚恐怖電影盤點']" href="https://movies.yahoo.com.tw/slideshow/-yahoo%E5%B9%B4%E5%BA%A6%E5%8D%81%E5%A4%A7%E5%B9%B4%E5%BA%A6%E6%9C%80%E5%9A%87-2019-%E5%8D%81%E5%A4%A7%E9%A9%9A%E6%82%9A%E6%81%90%E6%80%96%E9%9B%BB%E5%BD%B1%E7%9B%A4%E9%BB%9E-015046327.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/5g_.q2c3L1wZFyymRBLmPQ--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xMDc1O2g9NzE4Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/7a902560-25ef-11ea-bfff-31c138f35d45"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         【Yahoo年度十大】年度最嚇！2019十大驚悚恐怖電影盤點
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片8','重回黑幫本色！《紳士追殺令》釋出角色海報']" href="https://movies.yahoo.com.tw/slideshow/%E9%87%8D%E5%9B%9E%E9%BB%91%E5%B9%AB%E6%9C%AC%E8%89%B2%E7%B4%B3%E5%A3%AB%E8%BF%BD%E6%AE%BA%E4%BB%A4%E9%87%8B%E5%87%BA%E8%A7%92%E8%89%B2%E6%B5%B7%E5%A0%B1-003549174.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/gEx4zaYYPAyqdrzlk3659g--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz05OTI7aD0xNDE4Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/f0d7d7f0-25e4-11ea-bbf7-7ba3e186376a"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         重回黑幫本色！《紳士追殺令》釋出角色海報
#                       </span>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片9','星光熠熠！《星戰9》進軍東京紅毯']" href="https://movies.yahoo.com.tw/slideshow/%E6%98%9F%E5%85%89%E7%86%A0%E7%86%A0%E6%98%9F%E6%88%B0-9-%E9%80%B2%E8%BB%8D%E6%9D%B1%E4%BA%AC%E7%B4%85%E6%AF%AF-093858821.html">
# <div class="_slickcontent">
# <div class="foto"><img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/2Stj65fQuywlLeuFz9Ji1Q--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MTAwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/2a4b3620-1fe7-11ea-9fed-d5a52439c518"/>
# <div class="btn_openfoto"></div>
# </div>
# <div class="foto_info">
# <span class="text_truncate_2">
#                         星光熠熠！《星戰9》進軍東京紅毯
#                       </span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# <div class="btn_plus_more">
# <a class="gabtn" data-ga="['精彩圖片','精彩圖片_看更多','']" href="https://movies.yahoo.com.tw/tagged/slideshow">
# <div class="plus"></div>
#             看更多
#             </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="clearfix" id="footer" style="display: block;">
# <div id="loadbox">
# <a class="gabtn" data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank">服務中心</a> | <a class="gabtn" data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm" target="_blank">隱私權(更新)</a> | <a class="gabtn" data-ga="['其他連結','其他連結_建議','頁尾_其他連結']" href="https://yahoo.uservoice.com/forums/600523" target="_blank">建議</a> | <a class="gabtn" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/" target="_blank">關於我們的廣告</a>
#   | <a class="gabtn" data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank">服務條款(更新)</a>
#   | <a href="" target="_blank">
# </a>
#   由Yahoo奇摩電影 提供
# </div> </footer>
# </div>
# <!-- Javascript -->
# <script src="https://s.yimg.com/ss/rapid3.js"></script>
# <script src="https://s.yimg.com/ss/rapidworker-1.2.js"></script>
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   (function(d) {
#     var script = d.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/dy/ads/native.js";
#     d.body.appendChild(script);
#   })(document);
# </script>
# <script src="/build/js/app.js?id=73d7a35df24bf56129a3&amp;r=1555478321" type="text/javascript"></script>
# <noscript><img alt="" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=7241469&amp;c7=https%3A%2F%2Fmovies.yahoo.com.tw&amp;c5=794026701&amp;cv=2.0&amp;cj=1" width="1"/></noscript>
# <script>
# </script>
# <script src="https://s.yimg.com/uc/sf/latest/js/safe.min.js" type="text/javascript"></script>
# <script>
#     (function(win) {
#       if (win.OSafeframe && win.OSafeframe.initNPS) {
#         var surveyid = 'KS6MJDS'; // replace with the actual survey id for your property/region
#         var delay = 3000;   // replace the delay (in ms) that works best for your site to show survey 10 seconds after page content is visible
#         var surveylang = 'zh_Hant_TW';  // replace with the actual survey lang for your property/region
#         var wp = 'unknown';
#         win.OSafeframe.initNPS('nps-container', {
#           surveyid: surveyid, // required
#           lang: surveylang,   // optional
#           delay: delay, // required
#           wp: wp
#         }, {
#           pageLocale: 'zh_Hant_TW' // used for localizing the Close button. can be skipped if surveylang is defined, or en (or en-XX) is the language
#         });
#       } })(window);
#
# </script>
# <script type="application/javascript">
#   (function (w, d, t, r, u) {
#     w[u] = w[u] || []
#     w[u].push({
#       'projectId': '10000',
#       'properties': {
#         'pixelId': '428726',
#         'qstrings': {'country': 'tw', 'property': 'movie', 'tag': ''}
#       }
#     })
#     var s = d.createElement(t)
#     s.src = r
#     s.async = true
#     s.onload = s.onreadystatechange = function () {
#       var y, rs = this.readyState, c = w[u]
#       if (rs && rs != 'complete' && rs != 'loaded') {return}
#       try {
#         y = YAHOO.ywa.I13N.fireBeacon
#         w[u] = []
#         w[u].push = function (p) {y([p])}
#         y(c)
#       } catch (e) {}
#     }
#     var scr = d.getElementsByTagName(t)[0], par = scr.parentNode
#     par.insertBefore(s, scr)
#   })(window, document, 'script', 'https://s.yimg.com/wi/ytc.js', 'dotq')
# </script>
# </body>
# </html>

# %%
for i in soup.select('select.movie_name'):
    movie_item = i.select("option")
    for movie in movie_item:
        print(movie.text,movie['value'])
# Out:
# 請選擇片名
# 來自深淵 深沉靈魂的黎明  4DX/MX4D 10658
# 閉嘴！彈琴 10631
# 素人特工 10622
# 劇場版白箱 10621
# 老娘就要這麼活 10611
# 初戀 10607
# 黑暗戰域 10606
# 陪你玩最大 10602
# 觸不到的愛 10598
# 金都 10530
# 聽教父的話 10635
# 監禁100呎 10620
# 現屍報 10619
# 壞教育 10617
# 鎖命佈局 10616
# 正在相愛嗎？ 10615
# 見鬼的戀愛季節 10612
# 抽屍剝繭 10591
# 流感 10583
# 帕華洛帝：世紀男高音 10564
# 如果我擁抱你請不要害怕 10551
# 熊熊大作戰 10539
# 假面騎士令和時代的開端 10632
# 日暮 10603
# 無聲革命 10601
# 二階堂家物語 10597
# 惡之華 10587
# 蜈蚣降 10586
# 長沙里之戰：被遺忘的英雄 10585
# 靈異孤兒院 10584
# 數碼寶貝 LAST EVOLUTION 絆 10572
# 吞噬 10560
# 這一刻，想見你 10553
# 美好拾光公司 10541
# 緣來想見妳 10529
# 搭火車旅行好吃驚 10492
# 海上鋼琴師4K數位修復 10613
# 浪人47愁錢中 10596
# 戀愛倒帶中 10589
# 我的粉紅人生 10582
# 鑰命監獄 10579
# 罪：米開朗基羅 10574
# 居禮夫人：放射永恆 10537
# 知道天空有多藍的人啊 10526
# 築夢奇蹟 10511
# 末日異戰 10402
# 我不流行二十年 10614
# 樂來越愛你 10609
# 搞鬼 10570
# 政客誠實中 10563
# 女聲我最美 10528
# 來自深淵 深沉靈魂的黎明 10483
# 霸王別姬 10594
# 阿飛正傳 10593
# 羊男的迷宮 10580
# 犬鳴村 10543
# 間諜速成班 10538
# 我的英雄學院劇場版：英雄新世紀 10481
# 魔髮精靈唱遊世界 10466
# 絕命直播 10548
# 託陰2：布拉姆回來了 10540
# 抓住救命稻草的野獸們 10507
# Re從零開始的異世界生活 外傳集 10480
# 刺激1995 10518
# 劇場版 不起眼女主角培育法 Fine 10486
# 複製柔伊 10455
# 練愛iNG 10442
# 血衛 10469
# 明明會說話 10440
# 艾瑪 10396
# 鳴鳥不飛：烏雲密布 10458
# 女鬼橋 10437
# 怨咒 10421
# 極地守護犬 10383
# 隱形人 10359
# 電影音效傳奇：好萊塢之聲 10484
# 李察朱威爾事件 10368
# 音速小子 9246
# 逃出夢幻島 10485
# 猛禽小隊：小丑女大解放 10268
# 1917 10189
# 你的情歌 10407
# 杜立德 10316
# 她們 10202
# 變身特務 9008
# 巧虎電影：英雄遊樂園 10429
# 不完美的正義 10243
# 絕地戰警FOR LIFE 10242
# 驅魔直播 10375
# 兔嘲男孩 10283
# 潛艦追緝 10333
# 冰雪奇緣2 9597
# Hello World 10302
# 星際救援 10227
# 駭客任務 10088
# 幸福綠皮書 9150
# 魔女首部曲：誕生 8817
# 道別的早晨就用約定之花點綴吧 8292
# 不可能的任務：全面瓦解 7767
# 摩天大樓 8256
# 噤界 7509
# 遊戲人生Zero 7546
# 佈局 6814
# 玩命關頭8 6664
# 攻敵必救 6669
# 鋼鐵英雄 6436
# 列車上的女孩 6453
# 碧海藍天 6417
# 一首搖滾上月球 4887
# 錢不夠用2 3026

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print(f"Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 航海王：奪寶爭霸戰, ID: 10169
# Movie: 全面攻佔3：天使救援, ID: 10082
# Movie: 乾杯！戀上日本酒的女子, ID: 10131
# Movie: 普羅米亞, ID: 10119
# Movie: 怨靈少女組, ID: 10103
# Movie: 驅魔使者, ID: 10095
# Movie: 炫目之光, ID: 10066
# Movie: 飛翔吧！埼玉, ID: 9833
# Movie: 緝魔, ID: 9795
# Movie: 憤怒鳥玩電影2：冰的啦, ID: 10002
# Movie: 櫻花開了, ID: 10184
# Movie: 乘浪之約, ID: 10168
# Movie: 出發吧！我的脫單假期, ID: 10151
# Movie: 懸案判決, ID: 10142
# Movie: 怎麼就，結婚了, ID: 10133
# Movie: 絕世名伶, ID: 10132
# Movie: 是誰在搞鬼, ID: 10102
# Movie: 蠟筆小新：新婚旅行風暴─奪回廣志大作戰, ID: 10078
# Movie: 一定要結婚嗎, ID: 10074
# Movie: 朵拉與失落的黃金城, ID: 9920
# Movie: 在黑暗中說的鬼故事, ID: 10063
# Movie: 靈異乍現, ID: 9456
# Movie: 瑪雅蜜蜂大冒險：蜜糖危機, ID: 10139
# Movie: 痛苦與榮耀, ID: 10126
# Movie: 王的文字, ID: 10118
# Movie: 電梯男孩的奇蹟, ID: 10114
# Movie: 玩命關頭：特別行動, ID: 9582
# Movie: 出走巴黎, ID: 10140
# Movie: 鬼學怨, ID: 10135
# Movie: 駭客任務, ID: 10088
# Movie: 人生消極掰, ID: 10059
# Movie: 電影哆啦A夢：大雄的月球探測記, ID: 10016
# Movie: 從前，有個好萊塢, ID: 9884
# Movie: 王者天下, ID: 10125
# Movie: 首席指揮家, ID: 10116
# Movie: 電流大戰, ID: 10021
# Movie: 獅子王, ID: 9116
# Movie: 名偵探柯南：紺青之拳, ID: 9635
# Movie: 米開朗基羅：無盡之詩, ID: 10100
# Movie: 蜘蛛人：離家日, ID: 9467
# Movie: 寄生上流, ID: 10020
# Movie: 玩具總動員4, ID: 9924
# Movie: 帕爾曼的音樂遍歷, ID: 10070
# Movie: 劇場版 歌之王子殿下 真愛KINGDOM, ID: 10061
# Movie: CODE GEASS復活的魯路修, ID: 10056
# Movie: 阿拉丁, ID: 8938
# Movie: 復仇者聯盟：終局之戰, ID: 9728
# Movie: 霹靂嬌鋒, ID: 10188
# Movie: 七夜怪談2：貞子謎咒, ID: 10182
# Movie: 七夜怪談0：貞相大白, ID: 10181
# Movie: 七夜怪談：復活之路, ID: 10180
# Movie: 七夜怪談, ID: 10179

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10631

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 五月 15
# 五月 16
# 五月 17
# 五月 18
# 五月 19

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-05-18"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})

# %%
for i in soup.select("ul[data-theater_schedules]"):
    print(i["data-theater_name"])
#     print(i)
for d in soup.select('input[data-movie_date]'):
    print(d["data-movie_date"],d["data-movie_time"],d["data-movie_type"])
# Out:
# 喜樂時代影城南港店
# 05.18 13:15 數位
# 05.18 17:00 數位
