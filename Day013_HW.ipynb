# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
#
#
# 	<script async="" src="/cdn-cgi/bm/cv/2181903173/api.js"></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div class="bbs-content" id="topbar">
# 		<a href="/bbs/" id="logo">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
container=soup.select('.r-list-container .r-ent')
for title in container:
    for text in title.select('a'):
        print(text.text)
        for name in title.select('.author'):
            print(name.text)
# Out:
# [新聞] 喬丹鐵血領軍　巴克利酸：只挑軟隊友欺負
# pautaid
# 搜尋同標題文章
# pautaid
# 搜尋看板內 pautaid 的文章
# pautaid
# [花邊] 讚賈奈特競爭意識 皮爾斯：和喬丹是同等
# lovea
# 搜尋同標題文章
# lovea
# 搜尋看板內 lovea 的文章
# lovea
# [公告] 板規v6.8
# Vedan
# 搜尋同標題文章
# Vedan
# 搜尋看板內 Vedan 的文章
# Vedan
# [公告] 版主上任相關事項
# qazwsx879345
# 搜尋同標題文章
# qazwsx879345
# 搜尋看板內 qazwsx879345 的文章
# qazwsx879345
# [情報] SEASON Schedule 賽程 March 19–20
# Acetoxy
# 搜尋同標題文章
# Acetoxy
# 搜尋看板內 Acetoxy 的文章
# Acetoxy
# [公告] 第一次被退文，可在三天後刪除退文
# Vedan
# 搜尋同標題文章
# Vedan
# 搜尋看板內 Vedan 的文章
# Vedan
# [公告] 板務說明 (發錢)
# Vedan
# 搜尋同標題文章
# Vedan
# 搜尋看板內 Vedan 的文章
# Vedan

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Stock/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>看板 Stock 文章列表 - 批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
#
#
# 	<script async="" src="/cdn-cgi/bm/cv/2181903173/api.js"></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div class="bbs-content" id="topbar">
# 		<a href="/bbs/" id="logo">批踢踢實業坊</a>
# 		<span>›</span>
# ...

# %%
container=soup.select('.r-list-container .r-ent')
for title in container:
    for text in title.select('a'):
        print(text.text)
        for name in title.select('.author'):
            print(name.text)
# Out:
# [新聞] 台灣光罩虧損創上市來新高 股價一度跌停
# trex995
# 搜尋同標題文章
# trex995
# 搜尋看板內 trex995 的文章
# trex995
# [新聞] 中華電信攜手宏達電 拓展5G及VR市場
# peterlin495
# 搜尋同標題文章
# peterlin495
# 搜尋看板內 peterlin495 的文章
# peterlin495
# Re: [標的] 6203海韻電
# johncooi2003
# 搜尋同標題文章
# johncooi2003
# 搜尋看板內 johncooi2003 的文章
# johncooi2003
# [請益] 股利配發時間
# bud
# 搜尋同標題文章
# bud
# 搜尋看板內 bud 的文章
# bud
# [新聞] 中環取得取得台積電普通股股票之公告
# KSchuang
# 搜尋同標題文章
# KSchuang
# 搜尋看板內 KSchuang 的文章
# KSchuang
# Re: [標的] 4142 國光生 多
# sluttervagen
# 搜尋同標題文章
# sluttervagen
# 搜尋看板內 sluttervagen 的文章
# sluttervagen
# [請益] 股利扣稅問題
# bud
# 搜尋同標題文章
# bud
# 搜尋看板內 bud 的文章
# bud
# Re: [新聞]投資大咖唱衰美股 川普怒批：他們都在做空
# gk1329
# 搜尋同標題文章
# gk1329
# 搜尋看板內 gk1329 的文章
# gk1329
# [新聞] 財報：康那香(9919)109年第一季淨利歸屬3
# Levisyap
# 搜尋同標題文章
# Levisyap
# 搜尋看板內 Levisyap 的文章
# Levisyap
# [公告] 精華區導覽Q&A
# IanLi
# 搜尋同標題文章
# IanLi
# 搜尋看板內 IanLi 的文章
# IanLi
# [公告] Stock 板規V2.6             (2019/06/20)
# eyespot
# 搜尋同標題文章
# eyespot
# 搜尋看板內 eyespot 的文章
# eyespot
# [公告] 股票板板主徵選公告
# eyespot
# 搜尋同標題文章
# eyespot
# ...
