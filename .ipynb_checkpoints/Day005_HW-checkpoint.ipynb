# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests as rs
import json
r=rs.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data=json.loads(r.text)

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for d in data:
    print(d['title'])
    print(d['createdAt'])
    print(d['commentCount'])
    print(d['likeCount'])
print(d['title'] for d in data)
print(d['createdAt'] for d in data)
print(d['commentCount'] for d in data)
print(d['likeCount'] for d in data)
# Out:
# 看看他多奇怪
# 2020-05-05T11:43:02.462Z
# 16
# 230
# 🐶毛孩子😽在家一起防疫🏋🏻‍♂️的好吃好用組👍🏻
# 2020-05-06T06:04:02.907Z
# 0
# 213
# 我不會放棄 請你也不要放棄
# 2020-05-05T18:19:26.166Z
# 21
# 54
# 養了一隻灰白色的哈士奇 文長
# 2020-05-06T08:32:50.714Z
# 4
# 23
# 圍牆邊的一窩貓
# 2020-05-05T14:20:13.185Z
# 7
# 20
# #尋狗#協尋##高雄三民獅湖公園(賞金一萬元)
# 2020-05-05T13:56:46.429Z
# 3
# 20
# 爬蟲類寶貝們🐍
# 2020-05-05T13:55:48.114Z
# 24
# 19
# 離開前的最後一個作品
# 2020-05-05T17:02:17.212Z
# 10
# 17
# 我家可愛的博美❤️
# 2020-05-06T07:46:14.329Z
# 5
# 16
# 亞洲大學的可愛柴柴
# 2020-05-06T04:17:45.331Z
# 3
# 14
# 薯家三兄弟（三線鼠
# 2020-05-05T17:42:21.603Z
# 4
# 11
# 屬於我們的秘密
# 2020-05-05T13:55:35.731Z
# 1
# 11
# 拜託不要再用太空包了
# 2020-05-06T15:54:55.457Z
# 2
# 10
# 曬一下我家小惡魔
# 2020-05-06T07:56:22.195Z
# 3
# 9
# #美短 有一種冷是鏟屎官覺得你冷😹
# 2020-05-06T04:03:03.523Z
# 2
# 9
# 拜託這樣真的母湯
# 2020-05-06T04:15:25.858Z
# 2
# 8
# #走失
# 2020-05-05T12:36:47.664Z
# 0
# 8
# 很喜歡嘴巴開開的黃金鼠
# 2020-05-06T16:50:50.468Z
# 0
# 7
# 拜託領養代替購買
# 2020-05-06T15:36:40.865Z
# 1
# 7
# 有愛就美
# 2020-05-06T02:41:01.991Z
# 3
# 7
# 暴走の雙子座
# 2020-05-06T10:38:32.836Z
# 6
# 6
# #記得開聲音🔊 療癒的🐱吃播系列
# 2020-05-06T05:18:05.621Z
# 10
# 6
# （圖）請教，這是什麼的幼蛇？
# 2020-05-06T02:25:03.709Z
# 6
# 6
# 愈來愈像人類
# 2020-05-05T17:19:03.265Z
# 11
# 6
# 推個 捐飼料
# 2020-05-05T13:34:09.490Z
# 0
# 6
# 限時的這隻貓貓！！
# 2020-05-06T15:05:11.640Z
# 1
# 5
# 她也很奇怪🐦
# 2020-05-06T14:33:55.133Z
# 1
# 5
# #急尋 #台中市 #狗狗 #走失
# 5/6早上9點北屯區走失 請大家幫忙~
# 2020-05-06T04:06:48.988Z
# 2
# 5
# 殺手螺生寶寶了
# 2020-05-06T11:35:10.478Z
# 1
# 4
# 新手養兔子🐰
# 2020-05-05T16:00:09.397Z
# 9
# 4
# <generator object <genexpr> at 0x10cf2a650>
# <generator object <genexpr> at 0x10cf2a650>
# <generator object <genexpr> at 0x10cf2a650>
# <generator object <genexpr> at 0x10cf2a650>

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data), likeCount/len(data))

r = rs.get('https://www.dcard.tw/_api/forums/job/posts?popular=false')
response = r.text
data = json.loads(response)
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data), likeCount/len(data))
# Out:
# 5.266666666666667 25.533333333333335
# 2.6333333333333333 1.5333333333333334
